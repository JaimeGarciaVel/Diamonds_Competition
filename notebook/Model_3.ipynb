# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# %%
diamonds_df = pd.read_csv('../data/diamonds_train.csv')

# %%
diamonds_predict = pd.read_csv('../data/diamonds_test.csv')

# %%
#train

diamonds_df['cut']=diamonds_df['cut'].map({'Fair':0,'Good':1,'Very Good':2,'Premium':3, 'Ideal':4})
diamonds_df['color']=diamonds_df['color'].map({'J':0, 'I':1, 'H':2, 'G':3, 'F': 4, 'E': 5, 'D':6})
diamonds_df['clarity']=diamonds_df['clarity'].map({'I1':0,'SI2':1,'SI1':2,'VS2':3,'VS1':4,'VVS2':5,'VVS1':6,'IF':7})

#predict

diamonds_predict['cut']=diamonds_predict['cut'].map({'Fair':0,'Good':1,'Very Good':2,'Premium':3, 'Ideal':4})
diamonds_predict['color']=diamonds_predict['color'].map({'J':0, 'I':1, 'H':2, 'G':3, 'F': 4, 'E': 5, 'D':6})
diamonds_predict['clarity']=diamonds_predict['clarity'].map({'I1':0,'SI2':1,'SI1':2,'VS2':3,'VS1':4,'VVS2':5,'VVS1':6,'IF':7})

# %%
#train
diamonds_df['cut/carat'] = diamonds_df['cut']/diamonds_df['carat']
diamonds_df['color/carat'] = diamonds_df['color']/diamonds_df['carat']
diamonds_df['clarity/carat'] = diamonds_df['clarity']/diamonds_df['carat']
#predict
diamonds_predict['cut/carat'] = diamonds_predict['cut']/diamonds_predict['carat']
diamonds_predict['color/carat'] = diamonds_predict['color']/diamonds_predict['carat']
diamonds_predict['clarity/carat'] = diamonds_predict['clarity']/diamonds_predict['carat']

# %%
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import KFold, RepeatedKFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
sc = StandardScaler()
columns_df = ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z', 'cut/carat', 'color/carat', 'clarity/carat']
X = sc.fit_transform(diamonds_df[columns_df])
y = diamonds_df['price'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y)

# %%
model = GradientBoostingRegressor(n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print(f"Mean squared error: {mean_squared_error(y_test, y_pred, squared=False)}")
R2 = r2_score(y_test,y_pred)
print(f"R Squared: {R2}")
# Out:
# Mean squared error: 615.1147680665209
# R Squared: 0.9756367962462131

# %%
model = BaggingRegressor(n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print(f"Mean squared error: {mean_squared_error(y_test, y_pred, squared=False)}")
R2 = r2_score(y_test,y_pred)
print(f"R Squared: {R2}")
# Out:
# Mean squared error: 549.603650610512
# R Squared: 0.9805499238099208

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print(f"Mean squared error: {mean_squared_error(y_test, y_pred, squared=False)}")
R2 = r2_score(y_test,y_pred)
print(f"R Squared: {R2}")
# Out:
# Mean squared error: 550.0183559950925
# R Squared: 0.9805205604880018

# %%
import lightgbm as lgb

# %%
model = lgb.LGBMRegressor()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print(f"Mean squared error: {mean_squared_error(y_test, y_pred, squared=False)}")
R2 = r2_score(y_test,y_pred)
print(f"R Squared: {R2}")
# Out:
# Mean squared error: 534.7205342008929
# R Squared: 0.9815890663218281

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, 
                         X, 
                         y, 
                         scoring='neg_root_mean_squared_error', 
                         cv=10, n_jobs=-1)

# %%
import numpy as np
np.mean(-scores)
# Out:
# 535.2983093534878

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
FEATS = ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z', 'cut/carat', 'color/carat', 'clarity/carat']
TARGET ='price'
param_grid = {
    'preprocessor__num__imputer__strategy': ['mean', 'median'],
    'regressor__n_estimators': [16, 32, 64, 128, 256, 512],
    'regressor__max_depth': [2, 4, 8],
}

grid_search = RandomizedSearchCV(model, 
                                 param_grid, 
                                 cv=5, 
                                 verbose=10, 
                                 scoring='neg_root_mean_squared_error', 
                                 n_jobs=-1,
                                 n_iter=32)

grid_search.fit(diamonds_df[FEATS], diamonds_df[TARGET])
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 1/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.9s
# [CV 2/5; 1/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 1/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 3/5; 1/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 1/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.5s
# [CV 4/5; 1/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 1/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 5/5; 1/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 1/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 1/5; 2/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 2/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 2/5; 2/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 2/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.5s
# [CV 3/5; 2/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 2/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 4/5; 2/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 2/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.8s
# [CV 5/5; 2/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 2/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.8s
# [CV 1/5; 3/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 3/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.7s
# [CV 2/5; 3/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 3/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.6s
# [CV 3/5; 3/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 3/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.7s
# [CV 4/5; 3/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 3/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.9s
# [CV 5/5; 3/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 3/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.8s
# [CV 1/5; 4/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 4/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.6s
# [CV 2/5; 4/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 4/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.6s
# [CV 3/5; 4/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 4/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.7s
# [CV 4/5; 4/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 4/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16; total time=   1.0s
# [CV 5/5; 4/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 4/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.7s
# [CV 1/5; 5/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 5/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.7s
# [CV 2/5; 5/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 5/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 3/5; 5/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 5/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 4/5; 5/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 5/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 5/5; 5/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 5/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 1/5; 6/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 6/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.6s
# [CV 2/5; 6/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 6/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.7s
# [CV 3/5; 6/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 6/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.6s
# [CV 4/5; 6/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 6/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.6s
# [CV 5/5; 6/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 6/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.6s
# [CV 1/5; 7/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 7/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.7s
# [CV 2/5; 7/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 7/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.7s
# [CV 3/5; 7/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 7/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.6s
# [CV 4/5; 7/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 7/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.7s
# [CV 5/5; 7/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 7/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.8s
# [CV 1/5; 8/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 8/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64; total time=   0.6s
# [CV 2/5; 8/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 8/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64; total time=   0.6s
# [CV 3/5; 8/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 8/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64; total time=   0.6s
# [CV 4/5; 8/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 8/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64; total time=   0.6s
# [CV 5/5; 8/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 8/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=64; total time=   0.6s
# [CV 1/5; 9/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 9/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128; total time=   0.6s
# [CV 2/5; 9/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 9/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128; total time=   0.7s
# [CV 3/5; 9/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 9/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128; total time=   0.7s
# [CV 4/5; 9/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 9/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128; total time=   0.6s
# [CV 5/5; 9/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 9/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=128; total time=   0.6s
# [CV 1/5; 10/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 10/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.7s
# [CV 2/5; 10/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 10/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.7s
# [CV 3/5; 10/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 10/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.6s
# [CV 4/5; 10/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 10/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.6s
# [CV 5/5; 10/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 10/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=128; total time=   0.6s
# [CV 1/5; 11/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 11/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.6s
# [CV 2/5; 11/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 11/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.6s
# [CV 3/5; 11/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 11/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.6s
# [CV 4/5; 11/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 11/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.6s
# [CV 5/5; 11/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 11/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.6s
# [CV 1/5; 12/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 12/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 2/5; 12/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 12/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 3/5; 12/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 12/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.9s
# [CV 4/5; 12/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 12/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64; total time=   1.0s
# [CV 5/5; 12/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 12/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 1/5; 13/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 13/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16; total time=   0.6s
# [CV 2/5; 13/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 13/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16; total time=   0.6s
# [CV 3/5; 13/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 13/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16; total time=   0.6s
# [CV 4/5; 13/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 13/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16; total time=   0.6s
# [CV 5/5; 13/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 13/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=16; total time=   0.6s
# [CV 1/5; 14/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 14/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256; total time=   0.6s
# [CV 2/5; 14/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 14/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256; total time=   0.6s
# [CV 3/5; 14/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 14/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256; total time=   0.6s
# [CV 4/5; 14/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 14/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256; total time=   0.6s
# [CV 5/5; 14/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 14/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=2, regressor__n_estimators=256; total time=   0.6s
# [CV 1/5; 15/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 15/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512; total time=   0.6s
# [CV 2/5; 15/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 15/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512; total time=   0.6s
# [CV 3/5; 15/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 15/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512; total time=   0.6s
# [CV 4/5; 15/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 15/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512; total time=   0.6s
# [CV 5/5; 15/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 15/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=512; total time=   0.6s
# [CV 1/5; 16/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 16/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.7s
# [CV 2/5; 16/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 16/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 3/5; 16/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 16/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 4/5; 16/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 16/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 5/5; 16/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 16/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=64; total time=   0.6s
# [CV 1/5; 17/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 17/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 2/5; 17/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 17/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 3/5; 17/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 17/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 4/5; 17/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 17/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 5/5; 17/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 17/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=32; total time=   0.6s
# [CV 1/5; 18/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 18/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512; total time=   0.6s
# [CV 2/5; 18/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 18/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512; total time=   0.6s
# [CV 3/5; 18/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 18/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512; total time=   0.6s
# [CV 4/5; 18/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 18/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512; total time=   0.6s
# [CV 5/5; 18/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 18/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=512; total time=   0.6s
# [CV 1/5; 19/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 19/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.6s
# [CV 2/5; 19/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 19/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.6s
# [CV 3/5; 19/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 19/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.7s
# [CV 4/5; 19/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 19/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.6s
# [CV 5/5; 19/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 19/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=512; total time=   0.6s
# [CV 1/5; 20/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 20/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.7s
# [CV 2/5; 20/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 20/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.7s
# [CV 3/5; 20/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 20/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 4/5; 20/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 20/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 5/5; 20/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 20/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=32; total time=   0.6s
# [CV 1/5; 21/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 21/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 2/5; 21/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 21/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 3/5; 21/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 21/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 4/5; 21/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 21/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 5/5; 21/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 21/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=128; total time=   0.6s
# [CV 1/5; 22/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=8, regressor__n_estimators=512
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# ...
# [CV 2/5; 26/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64; total time=   0.6s
# [CV 3/5; 26/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 26/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64; total time=   0.8s
# [CV 4/5; 26/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 26/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64; total time=   0.6s
# [CV 5/5; 26/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 26/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=64; total time=   0.6s
# [CV 1/5; 27/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 27/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 2/5; 27/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 27/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.7s
# [CV 3/5; 27/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 27/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 4/5; 27/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 27/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 5/5; 27/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 27/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 1/5; 28/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 28/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32; total time=   0.6s
# [CV 2/5; 28/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 28/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32; total time=   0.6s
# [CV 3/5; 28/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 28/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32; total time=   0.6s
# [CV 4/5; 28/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 28/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32; total time=   0.6s
# [CV 5/5; 28/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 28/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=32; total time=   0.6s
# [CV 1/5; 29/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 29/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.7s
# [CV 2/5; 29/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 29/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.6s
# [CV 3/5; 29/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 29/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.6s
# [CV 4/5; 29/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 29/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.6s
# [CV 5/5; 29/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 29/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=2, regressor__n_estimators=16; total time=   0.6s
# [CV 1/5; 30/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 30/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 2/5; 30/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 30/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 3/5; 30/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 30/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 4/5; 30/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 30/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 5/5; 30/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 30/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=4, regressor__n_estimators=16; total time=   0.6s
# [CV 1/5; 31/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 31/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.6s
# [CV 2/5; 31/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 31/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.7s
# [CV 3/5; 31/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 31/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.7s
# [CV 4/5; 31/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 31/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.7s
# [CV 5/5; 31/32] START preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 31/32] END preprocessor__num__imputer__strategy=mean, regressor__max_depth=8, regressor__n_estimators=256; total time=   0.7s
# [CV 1/5; 32/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 1/5; 32/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.6s
# [CV 2/5; 32/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 2/5; 32/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.7s
# [CV 3/5; 32/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 3/5; 32/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256; total time=   1.0s
# [CV 4/5; 32/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 4/5; 32/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.8s
# [CV 5/5; 32/32] START preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# [CV 5/5; 32/32] END preprocessor__num__imputer__strategy=median, regressor__max_depth=4, regressor__n_estimators=256; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: regressor__max_depth
# [LightGBM] [Warning] Unknown parameter: regressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: preprocessor__num__imputer__strategy
# RandomizedSearchCV(cv=5, estimator=LGBMRegressor(), n_iter=32, n_jobs=-1,
#                    param_distributions={'preprocessor__num__imputer__strategy': ['mean',
#                                                                                  'median'],
#                                         'regressor__max_depth': [2, 4, 8],
#                                         'regressor__n_estimators': [16, 32, 64,
#                                                                     128, 256,
#                                                                     512]},
#                    scoring='neg_root_mean_squared_error', verbose=10)

# %%
grid_search.best_params_
# Out:
# {'regressor__n_estimators': 128,
#  'regressor__max_depth': 8,
#  'preprocessor__num__imputer__strategy': 'mean'}

# %%
grid_search.best_score_
# Out:
# -536.7962721908281

# %%
y_pred = grid_search.predict(diamonds_predict[FEATS])

# %%
submission_df = pd.DataFrame({'id': diamonds_predict['id'], 'price': y_pred})

# %%
submission_df.to_csv('../data/resultados7.csv', index=False)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()


#X_test = sc.transform(diamonds_predict[columns_df].values)
#y_hat = model.predict(X_test).clip(0, 20000)
#submission = pd.DataFrame({'id': diamonds_predict['id'], 'price': y_hat})
#submission.to_csv('../data/resultados5.csv', index=False)
